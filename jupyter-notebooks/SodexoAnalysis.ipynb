# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('sodexo.csv',index_col='Date', parse_dates=True)
                 
df.head()
# Out:
#                      Unnamed: 0  Card type  Transaction ID  \
# Date
# 2019-05-11 17:37:01           0  Meal card   1242131289530
# 2019-05-11 16:28:31           1  Meal card   1242091281757
# 2019-05-11 13:04:23           2  Meal card   1242231228412
# 2019-05-11 09:56:04           3  Meal card   1242071209902
# 2019-05-11 09:47:29           4  Meal card   1242111207177
#
#                                          Transaction Details Credit(in Rs.)  \
# Date
# 2019-05-11 17:37:01        SODEXO FOOD SOLUTIONS (I) PVT LTD           0.00
# 2019-05-11 16:28:31  CAPGEMINI TECHNOLOGY SERVICES INDIA LTD       2,000.00
# 2019-05-11 13:04:23        SODEXO FOOD SOLUTIONS (I) PVT LTD           0.00
# 2019-05-11 09:56:04        SODEXO FOOD SOLUTIONS (I) PVT LTD           0.00
# 2019-05-11 09:47:29        SODEXO FOOD SOLUTIONS (I) PVT LTD           0.00
#
#                      Debit(in Rs.) Previous Balance(in Rs.)  \
# Date
# 2019-05-11 17:37:01           35.0                 4,273.00
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Card type', 'Transaction ID', 'Transaction Details',
#        'Credit(in Rs.)', 'Debit(in Rs.)', 'Previous Balance(in Rs.)',
#        'New Balance(in Rs.)'],
#       dtype='object')

# %%
df2 = df[['Debit(in Rs.)']]
df2.columns = ['debit']

df2 = df2.resample('1D').sum()

df2.head()
# Out:
#             debit
# Date
# 2019-01-07  124.0
# 2019-01-08  143.0
# 2019-01-09    0.0
# 2019-01-10  159.0
# 2019-01-11  145.0

# %%
import matplotlib
# %matplotlib inline
df2.plot(figsize=(12,5))

# %%
df2['debit']['2019-10-01':].plot(figsize=(12,5))

# %%
df3 = df2.copy()

df3 = df2.resample('1W').sum()


df3.head()
# Out:
#             debit
# Date
# 2019-01-13  571.0
# 2019-01-20    0.0
# 2019-01-27    0.0
# 2019-02-03    0.0
# 2019-02-10  125.0

# %%
df3.plot(figsize=(12,5))

# %%
from statsmodels.tsa.seasonal seasonal_decompose
# Out:
#   File "<ipython-input-27-5c8a229e4894>", line 1
#     from statsmodels.tsa.seasonal seasonal_decompose
#                                                    ^
# SyntaxError: invalid syntax
